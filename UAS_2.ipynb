# %% [markdown]
# <a href="https://colab.research.google.com/github/sanenchan/UAS-Machine-Learning/blob/main/UAS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
from textblob import TextBlob
import pandas as pd
import numpy as np
import re,string
import matplotlib.pyplot as plt 
plt.style.use('fivethirtyeight')

from nltk.corpus import stopwords
from wordcloud import WordCloud,STOPWORDS

import csv

# %%
consumer_key = "77FBm5yhuqaut06hqozP8O8EV"
consumer_secret_key ="g1KgZvx5uNWsxJE3wLVvwMYXlEHIYcPOmrBIwaIbbGmalr327T"
access_token = "1295686074971254784-MXtqxjOUQTiuqbApfUVFNcoe9xCPVb"
access_token_secret = "1I64e9Ch3n0vJSK8dEyVMMrFeskUovU7NXqxhQTOBml2i"

auth = tweepy.OAuthHandler(consumer_key,consumer_secret_key)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
csvFile = open('gojek.csv','a', encoding='utf-8')
csvWriter = csv.writer(csvFile)
for tweet in tweepy.Cursor(api.search, q= "#gojek",count=100, 
                          lang='id').items(3000):
    print(tweet.text)
    csvWriter.writerow([tweet.text])
# Out:
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Tokopedia dan Gojek dikabarkan akan melakukan merger.  Bila dua perusahaan startup ini bergabung diperkirakan nilai… https://t.co/YVd3mTmHaL
# Anter barang tanpa repot ? #GoSend-in Aja, dan mulai #HidupTanpaBatas dengan #Gojek follow kita ya di GojekTomohon, kaka
# Collab nya ga main main widiw
#
# #kpop #Tokopedia #gojek #smtown #JYP https://t.co/kYE6VzyMav
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon
# Sidoli Pargojek (Sidoli Parmotor) | Artis Pemuda Batak Bersatu DPC Kab. Karimun | Cover Lagu Batak… https://t.co/EGIVtd1qXn
# Kini Gojek telah hadir di Kota Tomohon, satu aplikasi untuk segala kebutuhanmu.
# Download #Gojek dan mulai # ##HidupTanpaBatas #GojekTomohon
# Pake #Go-Ride, lebih dekat dan lebih mudah
# Download #Gojek, dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# RT @detikinet: Gojek dikabarkan sedang dalam pembicaraan terkait kemungkinan melakukan merger dengan Tokopedia. Jika benar, kesepakatan itu…
# RT @detikinet: Gojek dikabarkan sedang dalam pembicaraan terkait kemungkinan melakukan merger dengan Tokopedia. Jika benar, kesepakatan itu…
# Gojek dikabarkan sedang dalam pembicaraan terkait kemungkinan melakukan merger dengan Tokopedia. Jika benar, kesepa… https://t.co/0wAeXFNpcs
# RT @detikinet: Ada campur tangan orang terkaya Jepang, Masayoshi Son, di balik kabar rencana merger Gojek dan Tokopedia. Pemilik SoftBank G…
# @mabadokter21 Pasti ada jalan #gojek
# Ada campur tangan orang terkaya Jepang, Masayoshi Son, di balik kabar rencana merger Gojek dan Tokopedia. Pemilik S… https://t.co/dLXJmyxItg
# Santer Isu Merger Gojek dan Tokopedia https://t.co/YJoLrcnX8s #Headline #LatestNews #News #Gojek #GojekTokopedia
# Bloomberg memberitakan 2 raksasa startup Gojek dan Tokopedia berencana merger. Ini tanggapan Gojek. #Gojek… https://t.co/TT6RmZPkhT
# Kabar yang menyebutkan Gojek akan merger dengan Tokopedia tampaknya disambut baik banyak pihak. Pengamat menilai, G… https://t.co/50xw4KJTp4
# Phishing #gojek : gojek[.]vip
# cc: @gojektech #Phishing
# @detikfinance #kafein akankan 2 saham terkait #gojek naik : #arto #bird.
# Gojek dikabarkan sedang dalam pembicaraan terkait kemungkinan melakukan merger dengan Tokopedia.
an mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# @chduu sahabat ijo #grab #gojek 👍🏻
# Bayar tagihan segampang itu, #GoBill jadi solusinya  Download #Gojek sekarang, nikmati #HidupTanpaBatas bersama #GojekTomohon
# Kini Gojek telah hadir di Kota Tomohon, satu aplikasi untuk segala kebutuhanmu.
# Download #Gojek dan mulai # ##HidupTanpaBatas #GojekTomohon
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Pake #Go-Ride, lebih dekat dan lebih mudah
# Download #Gojek, dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kini Gojek telah hadir di Kota Tomohon, satu aplikasi untuk segala kebutuhanmu.
# Download #Gojek dan mulai # ##HidupTanpaBatas #GojekTomohon
# Gais ada yang mau main suwit bareng kah? 🥺🥺 Kita bikin seri supaya sama sama untung 🥺🥺🥺
# #gopay
# #gojek
# #suwit
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon
# Tampilan oke cuman pas dipake ngebingungin...
# Yg kasian Mama ku...
# Skrg beliau lebih pilih aplikasi satunya karen… https://t.co/XGL5q905cJ
# Malam2 laper tapi males keluar ? #GoFood-in Aja Download #Gojek sekarang, nikmati #HidupTanpaBatas bersama #GojekTomohon
# RT @mf_anolyte1: 🍀Anolyte AG Jerigen 1 liter - HAND &amp; FACE SANITIZER🍀
#
# Non Alkohol #Sanitizer #HOCI Halal MUI.
#
# Harga    : Rp110.000.
# Link…
# Pake #Go-Ride, lebih dekat dan lebih mudah
# Download #Gojek, dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Jalan2 tanpa repot ? #Goride-in Aja mulai #HidupTanpaBatas dengan #Gojek follow kita ya di GojekTomohon
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon
# RT @mf_anolyte1: 🍀Anolyte AG Jerigen 1 liter - HAND &amp; FACE SANITIZER🍀
#
# Non Alkohol #Sanitizer #HOCI Halal MUI.
#
# Harga    : Rp110.000.
# Link…
# RT @mf_anolyte1: 🍀Anolyte AG Jerigen 1 liter - HAND &amp; FACE SANITIZER🍀
#
# Non Alkohol #Sanitizer #HOCI Halal MUI.
#
# Harga    : Rp110.000.
# Link…
# 🍀Anolyte AG Jerigen 1 liter - HAND &amp; FACE SANITIZER🍀
#
# Non Alkohol #Sanitizer #HOCI Halal MUI.
#
# Harga    : Rp110.000… https://t.co/chLw0wuwNW
# Kini Gojek telah hadir di Kota Tomohon, satu aplikasi untuk segala kebutuhanmu.
# Download #Gojek dan mulai # ##HidupTanpaBatas #GojekTomohon
# Pake #Go-Ride, lebih dekat dan lebih mudah
# Download #Gojek, dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Ada ga suwitnya yg blm limit? Maen sama aku yuk! 📌cari yg AMANAH yaa no lying &amp; playing victim:) thx XOXO #suwit #gojek
# Indahnya bisa Berbagi sama Abang2 Ojol
#
# #ojol #ojolindonesia #grab #gojek #gojekindonesia #online #indahnyaberbagi… https://t.co/R5Ofep0V27
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon
# Kini Gojek telah hadir di Kota Tomohon, satu aplikasi untuk segala kebutuhanmu.
# Download #Gojek dan mulai # ##HidupTanpaBatas #GojekTomohon
# Mohon info utk pembayaran gopay later mengalami gangguan sudah bbrp hari ini. Ini sdh tgl jatuh tempo, bagaimana ca… https://t.co/mER1haBjiv
# Pake #Go-Ride, lebih dekat dan lebih mudah
# Download #Gojek, dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon
# Pake #Go-Ride, lebih dekat dan lebih mudah
# Download #Gojek, dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kini Gojek telah hadir di Kota Tomohon, satu aplikasi untuk segala kebutuhanmu.
# Download #Gojek dan mulai # ##HidupTanpaBatas #GojekTomohon
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Driver gojek lagi mlm tahun batuan
#
# #nanas #bakar #tahunbaru2021 #kemana #gojek #gofood
# Makan tanpa masak ? #GoFood-in Aja Download #Gojek sekarang, nikmati #HidupTanpaBatas bersama #GojekTomohon
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon
# Bayar tagihan segampang itu, #GoBill jadi solusinya  Download #Gojek sekarang, nikmati #HidupTanpaBatas bersama #GojekTomohon
# Kemana aja tanpa susah, #GoRide solusinya Download #Gojek sekarang, nikmati #HidupTanpaBatas bersama #GojekTomohon
# Jalan2 tanpa repot ? #Goride-in Aja mulai #HidupTanpaBatas dengan #Gojek follow kita ya di GojekTomohon
# Pake #Go-Ride, lebih dekat dan lebih mudah
# Download #Gojek, dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kenyang tanpa masak ? #GoFood-in aja
# Download #Gojek dan mulai #HidupTanpaBatas di Tomohon ##HidupTanpaBatas #GojekTomohon
# Kini Gojek telah hadir di Kota Tomohon, satu aplikasi untuk segala kebutuhanmu.
# Download #Gojek dan mulai # ##HidupTanpaBatas #GojekTomohon
# Kirim orderan OL-shop lancar tanpa ribet ngantar, #GoSend solusinya.
# Download #Gojek dan mulai #HidupTanpa ##HidupTanpaBatas #GojekTomohon

# %%
df = pd.read_csv("gojek.csv", header=None)
df
# Out:
#                                                       0
# 0                             @Putrinrsmw ga #grab bun?
# 1     RT @kreffsdrop: Nih gue kasih token SLP yg tak...
# 2     Hy Smileys\n\nFree ongkir via grab setiap pemb...
# 3     RT @kreffsdrop: Nih gue kasih token SLP yg tak...
# 4     RT @kreffsdrop: Nih gue kasih token SLP yg tak...
# ...                                                 ...
# 2635  Kenyang tanpa masak ? #GoFood-in aja\nDownload...
# 2636  Driver gojek lagi mlm tahun batuan\n\n#nanas #...
# 2637  Makan tanpa masak ? #GoFood-in Aja Download #G...
# 2638  Kirim orderan OL-shop lancar tanpa ribet ngant...
# 2639  Bayar tagihan segampang itu, #GoBill jadi solu...
#
# [2640 rows x 1 columns]

# %%
def praproses(teks):
    teks = re.sub(r'http\S+','',teks)
    teks = hapus_tanda(teks)
    teks = re.sub(r'#([^\s]+)', r'\1', teks) #hapus #tagger
    teks = re.sub('@[A-Za-z0-9]+', '',teks)  #hapus @
    teks = re.sub(r':([^\s]+)', r'\1', teks) #hapus #tagger
    teks = re.sub('RT[\s]+', '',teks)#hapus RT
    teks = re.sub('https?:\/\/\S+', '',teks)#hapus hyperlink
    teks = re.sub(r'\w*\d\w*', '',teks).strip()#hapus angka dan angka yang berada dalam string
    teks = hapus_katadouble(teks)#hapus repetisi karakter
    teks = teks.lower() #ubah jadi lower case
#     teks = to_kbbi(teks)
    return teks

def hapus_tanda(teks): 
    tanda_baca = set(string.punctuation)
    tanda_baca.update(['…'])
    teks = ''.join(ch for ch in teks if ch not in tanda_baca)
    return teks

def hapus_katadouble(s): 
    #look for 2 or more repetitions of character and replace with the character itself
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", s)

def kbbi(kata): # penyeragaman kata berdasarkan kbbi 
	#kbba = [kamus.strip('\n').strip('\r') for kamus in open('kamus\\kbba.txt')]
	kamus_kata = [kamus.strip('\n').strip('\r') for kamus in open('kbba.txt')]
	#ubah list menjadi dictionary 
	dic = {}
	for i in kamus_kata: 
		(key, val) = i.split('\t')
		dic[str(key)] = val
	#kbbi cocokan 
	final_string = ' '.join(str(dic.get(word, word)) for word in kata).split()
	return final_string

def to_kbbi(teks):
    teks = teks.split()
    teks = kbbi(teks)
    return teks

#Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop_w:
            final_text.append(i.strip())
    return " ".join(final_text)

def hapus_emoji(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

#Removing the noisy text
def cleanText(text):
    text = remove_stopwords(text)
    text = praproses(text)
    text = hapus_emoji(text)
    return text

# Load stopword Bahasa Indonesia
stopword_id = pd.read_csv('stopword_id.csv', sep='\t', header=None)
stopword_id.columns = ['word']
stop_w = stopword_id['word'].to_list() #diubah ke list 
# print('ada' in stop_w) # test periksa kata di dalam list stop_w

# def cleanText(teks):
#     teks = re.sub('@[A-Za-z0-9]+', '',teks)  #hapus @
#     teks = re.sub(r'#([^\s]+)', r'\1', teks) #hapus #tagger
#     teks = re.sub('RT[\s]+', '',teks)#hapus RT
#     teks = re.sub('https?:\/\/\S+', '',teks)#hapus hyperlink
#     teks = teks.lower() #ubah jadi lower case
#     teks = re.sub(r"[-()\"#/@;:<>{}=~|.?,]", "", teks)
#     import string
#     killpunctuation = str.maketrans('', '', string.punctuation)
#     return teks

#Apply function on review column
df[0] = df[0].apply(cleanText)

df
# Out:
#                                                       0
# 0                                putrinrsmw ga grab bun
# 1     kreffsdrop nih gue kasih token slp yg berharga...
# 2     hy smileys free ongkir via grab pembelanjaan m...
# 3     kreffsdrop nih gue kasih token slp yg berharga...
# 4     kreffsdrop nih gue kasih token slp yg berharga...
# ...                                                 ...
# 2635  kenyang masak  gofoodin aja download gojek hid...
# 2636  driver gojek mlm batuan nanas bakar  kemana go...
# 2637  makan masak  gofoodin aja download gojek sekar...
# 2638  kirim orderan olshop lancar ribet ngantar gose...
# 2639  bayar tagihan segampang itu gobill solusinya d...
#
# [2640 rows x 1 columns]

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity


df['Polarity'] = df[0].apply(getPolarity)
df['Subjectivity'] = df[0].apply(getSubjectivity)

df
# Out:
#                                                       0  ...  Analysis
# 0                                putrinrsmw ga grab bun  ...   Neutral
# 1     kreffsdrop nih gue kasih token slp yg berharga...  ...   Neutral
# 2     hy smileys free ongkir via grab pembelanjaan m...  ...  Positive
# 3     kreffsdrop nih gue kasih token slp yg berharga...  ...   Neutral
# 4     kreffsdrop nih gue kasih token slp yg berharga...  ...   Neutral
# ...                                                 ...  ...       ...
# 2635  kenyang masak  gofoodin aja download gojek hid...  ...   Neutral
# 2636  driver gojek mlm batuan nanas bakar  kemana go...  ...   Neutral
# 2637  makan masak  gofoodin aja download gojek sekar...  ...   Neutral
# 2638  kirim orderan olshop lancar ribet ngantar gose...  ...   Neutral
# 2639  bayar tagihan segampang itu gobill solusinya d...  ...   Neutral
#
# [2640 rows x 4 columns]

# %%
allWords =' '.join([twts for twts in df[0]])
wc = WordCloud(width = 500 , height = 300 , random_state=10, max_font_size=110).generate(allWords)
plt.imshow(wc , interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
#untuk menambahkan sentimen positif, negatif / netral dari polarity yg sudah dihitung
def getAnalysisSentiment(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
        
df['Analysis'] = df['Polarity'].apply(getAnalysisSentiment)

df
# Out:
#                                                       0  ...  Analysis
# 0                                putrinrsmw ga grab bun  ...   Neutral
# 1     kreffsdrop nih gue kasih token slp yg berharga...  ...   Neutral
# 2     hy smileys free ongkir via grab pembelanjaan m...  ...  Positive
# 3     kreffsdrop nih gue kasih token slp yg berharga...  ...   Neutral
# 4     kreffsdrop nih gue kasih token slp yg berharga...  ...   Neutral
# ...                                                 ...  ...       ...
# 2635  kenyang masak  gofoodin aja download gojek hid...  ...   Neutral
# 2636  driver gojek mlm batuan nanas bakar  kemana go...  ...   Neutral
# 2637  makan masak  gofoodin aja download gojek sekar...  ...   Neutral
# 2638  kirim orderan olshop lancar ribet ngantar gose...  ...   Neutral
# 2639  bayar tagihan segampang itu gobill solusinya d...  ...   Neutral
#
# [2640 rows x 4 columns]

# %%
plt.figure(figsize=(8,6))
for i in range(0, df.shape[0]):
    plt.scatter(df["Polarity"][i], df["Subjectivity"][i], color="Blue")
    
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
df['Analysis'].value_counts()
# Out:
# Neutral     2438
# Positive     181
# Negative      21
# Name: Analysis, dtype: int64

# %%
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind ='bar')
plt.show()
